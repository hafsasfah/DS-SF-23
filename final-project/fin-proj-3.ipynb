# %%
import os
import fnmatch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn import linear_model, cross_validation

pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv(os.path.join('.', '', 'abalone-data.csv'))

# %%
df
# Out:
#      Sex  Length  Diameter  Height  WholeWeight  ShuckedWeight  VisceraWeight  \
# 0      M   0.455     0.365   0.095       0.5140         0.2245         0.1010
# 1      M   0.350     0.265   0.090       0.2255         0.0995         0.0485
# 2      F   0.530     0.420   0.135       0.6770         0.2565         0.1415
# 3      M   0.440     0.365   0.125       0.5160         0.2155         0.1140
# 4      I   0.330     0.255   0.080       0.2050         0.0895         0.0395
# ...   ..     ...       ...     ...          ...            ...            ...
# 4172   F   0.565     0.450   0.165       0.8870         0.3700         0.2390
# 4173   M   0.590     0.440   0.135       0.9660         0.4390         0.2145
# 4174   M   0.600     0.475   0.205       1.1760         0.5255         0.2875
# 4175   F   0.625     0.485   0.150       1.0945         0.5310         0.2610
# 4176   M   0.710     0.555   0.195       1.9485         0.9455         0.3765
#
#       ShellWeight  Rings
# 0          0.1500     15
# 1          0.0700      7
# 2          0.2100      9
# 3          0.1550     10
# 4          0.0550      7
# ...           ...    ...
# 4172       0.2490     11
# 4173       0.2605     10
# 4174       0.3080      9
# 4175       0.2960     10
# 4176       0.4950     12
#
# [4177 rows x 9 columns]

# %% [markdown]
# Approximate abalone dating rule: Age = Rings + 1.5

# %%
df.dropna(inplace = True) # Let's drop the NaN (none should exist in this dataset)

# %%
df.columns
# Out:
# Index([u'Sex', u'Length', u'Diameter', u'Height', u'WholeWeight',
#        u'ShuckedWeight', u'VisceraWeight', u'ShellWeight', u'Rings'],
#       dtype='object')

# %%
df.Rings.value_counts()
# Out:
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
#      ...
# 1       1
# 25      1
# 2       1
# 26      1
# 29      1
# Name: Rings, dtype: int64

# %%
df.corr()
# Out:
#                  Length  Diameter    Height  WholeWeight  ShuckedWeight  \
# Length         1.000000  0.986812  0.827554     0.925261       0.897914
# Diameter       0.986812  1.000000  0.833684     0.925452       0.893162
# Height         0.827554  0.833684  1.000000     0.819221       0.774972
# WholeWeight    0.925261  0.925452  0.819221     1.000000       0.969405
# ShuckedWeight  0.897914  0.893162  0.774972     0.969405       1.000000
# VisceraWeight  0.903018  0.899724  0.798319     0.966375       0.931961
# ShellWeight    0.897706  0.905330  0.817338     0.955355       0.882617
# Rings          0.556720  0.574660  0.557467     0.540390       0.420884
#
#                VisceraWeight  ShellWeight     Rings
# Length              0.903018     0.897706  0.556720
# Diameter            0.899724     0.905330  0.574660
# Height              0.798319     0.817338  0.557467
# WholeWeight         0.966375     0.955355  0.540390
# ShuckedWeight       0.931961     0.882617  0.420884
# VisceraWeight       1.000000     0.907656  0.503819
# ShellWeight         0.907656     1.000000  0.627574
# Rings               0.503819     0.627574  1.000000

# %%
df.Rings.unique()
# Out:
# array([15,  7,  9, 10,  8, 20, 16, 19, 14, 11, 12, 18, 13,  5,  4,  6, 21,
#        17, 22,  1,  3, 26, 23, 29,  2, 27, 25, 24])

# %%
df.Diameter.unique()
# Out:
# array([ 0.365,  0.265,  0.42 ,  0.255,  0.3  ,  0.415,  0.425,  0.37 ,
#         0.44 ,  0.38 ,  0.35 ,  0.405,  0.355,  0.4  ,  0.28 ,  0.34 ,
#         0.295,  0.32 ,  0.275,  0.48 ,  0.45 ,  0.445,  0.475,  0.47 ,
#         0.56 ,  0.525,  0.55 ,  0.29 ,  0.335,  0.175,  0.15 ,  0.375,
#         0.245,  0.41 ,  0.36 ,  0.31 ,  0.385,  0.19 ,  0.345,  0.325,
#         0.495,  0.39 ,  0.235,  0.51 ,  0.465,  0.535,  0.435,  0.43 ,
#         0.395,  0.305,  0.195,  0.54 ,  0.26 ,  0.2  ,  0.33 ,  0.23 ,
#         0.285,  0.52 ,  0.455,  0.205,  0.13 ,  0.5  ,  0.515,  0.485,
#         0.46 ,  0.545,  0.57 ,  0.575,  0.16 ,  0.21 ,  0.49 ,  0.25 ,
#         0.27 ,  0.505,  0.215,  0.225,  0.055,  0.1  ,  0.09 ,  0.12 ,
#         0.53 ,  0.145,  0.22 ,  0.6  ,  0.58 ,  0.585,  0.565,  0.555,
#         0.185,  0.165,  0.125,  0.59 ,  0.14 ,  0.11 ,  0.155,  0.315,
#         0.24 ,  0.17 ,  0.18 ,  0.105,  0.595,  0.135,  0.625,  0.63 ,
#         0.61 ,  0.65 ,  0.62 ,  0.605,  0.095,  0.115,  0.615])

# %%
df.Height.unique()
# Out:
# array([ 0.095,  0.09 ,  0.135,  0.125,  0.08 ,  0.15 ,  0.14 ,  0.11 ,
#         0.145,  0.1  ,  0.13 ,  0.085,  0.155,  0.165,  0.185,  0.18 ,
#         0.175,  0.2  ,  0.105,  0.045,  0.055,  0.05 ,  0.12 ,  0.07 ,
#         0.16 ,  0.06 ,  0.17 ,  0.195,  0.19 ,  0.115,  0.075,  0.065,
#         0.215,  0.21 ,  0.23 ,  0.205,  0.22 ,  0.04 ,  0.01 ,  0.03 ,
#         0.035,  0.225,  0.24 ,  0.235,  0.02 ,  0.025,  0.015,  0.   ,
#         0.515,  0.25 ,  1.13 ])

# %% [markdown]
# Height has bad "0." values.

# %%
df
# Out:
#      Sex  Length  Diameter  Height  WholeWeight  ShuckedWeight  VisceraWeight  \
# 0      M   0.455     0.365   0.095       0.5140         0.2245         0.1010
# 1      M   0.350     0.265   0.090       0.2255         0.0995         0.0485
# 2      F   0.530     0.420   0.135       0.6770         0.2565         0.1415
# 3      M   0.440     0.365   0.125       0.5160         0.2155         0.1140
# 4      I   0.330     0.255   0.080       0.2050         0.0895         0.0395
# ...   ..     ...       ...     ...          ...            ...            ...
# 4172   F   0.565     0.450   0.165       0.8870         0.3700         0.2390
# 4173   M   0.590     0.440   0.135       0.9660         0.4390         0.2145
# 4174   M   0.600     0.475   0.205       1.1760         0.5255         0.2875
# 4175   F   0.625     0.485   0.150       1.0945         0.5310         0.2610
# 4176   M   0.710     0.555   0.195       1.9485         0.9455         0.3765
#
#       ShellWeight  Rings
# 0          0.1500     15
# 1          0.0700      7
# 2          0.2100      9
# 3          0.1550     10
# 4          0.0550      7
# ...           ...    ...
# 4172       0.2490     11
# 4173       0.2605     10
# 4174       0.3080      9
# 4175       0.2960     10
# 4176       0.4950     12
#
# [4177 rows x 9 columns]

# %%
# Drop the 0. Height value(s)
df = df[df.Height != 0.]

# %%
df
# Out:
#      Sex  Length  Diameter  Height  WholeWeight  ShuckedWeight  VisceraWeight  \
# 0      M   0.455     0.365   0.095       0.5140         0.2245         0.1010
# 1      M   0.350     0.265   0.090       0.2255         0.0995         0.0485
# 2      F   0.530     0.420   0.135       0.6770         0.2565         0.1415
# 3      M   0.440     0.365   0.125       0.5160         0.2155         0.1140
# 4      I   0.330     0.255   0.080       0.2050         0.0895         0.0395
# ...   ..     ...       ...     ...          ...            ...            ...
# 4172   F   0.565     0.450   0.165       0.8870         0.3700         0.2390
# 4173   M   0.590     0.440   0.135       0.9660         0.4390         0.2145
# 4174   M   0.600     0.475   0.205       1.1760         0.5255         0.2875
# 4175   F   0.625     0.485   0.150       1.0945         0.5310         0.2610
# 4176   M   0.710     0.555   0.195       1.9485         0.9455         0.3765
#
#       ShellWeight  Rings
# 0          0.1500     15
# 1          0.0700      7
# 2          0.2100      9
# 3          0.1550     10
# 4          0.0550      7
# ...           ...    ...
# 4172       0.2490     11
# 4173       0.2605     10
# 4174       0.3080      9
# 4175       0.2960     10
# 4176       0.4950     12
#
# [4175 rows x 9 columns]

# %%
df.Height.unique()
# Out:
# array([ 0.095,  0.09 ,  0.135,  0.125,  0.08 ,  0.15 ,  0.14 ,  0.11 ,
#         0.145,  0.1  ,  0.13 ,  0.085,  0.155,  0.165,  0.185,  0.18 ,
#         0.175,  0.2  ,  0.105,  0.045,  0.055,  0.05 ,  0.12 ,  0.07 ,
#         0.16 ,  0.06 ,  0.17 ,  0.195,  0.19 ,  0.115,  0.075,  0.065,
#         0.215,  0.21 ,  0.23 ,  0.205,  0.22 ,  0.04 ,  0.01 ,  0.03 ,
#         0.035,  0.225,  0.24 ,  0.235,  0.02 ,  0.025,  0.015,  0.515,
#         0.25 ,  1.13 ])

# %% [markdown]
# Confirmed that the 0 value is gone.

# %%
df.Length.unique()
# Out:
# array([ 0.455,  0.35 ,  0.53 ,  0.44 ,  0.33 ,  0.425,  0.545,  0.475,
#         0.55 ,  0.525,  0.43 ,  0.49 ,  0.535,  0.47 ,  0.5  ,  0.355,
#         0.365,  0.45 ,  0.38 ,  0.565,  0.615,  0.56 ,  0.58 ,  0.59 ,
#         0.605,  0.575,  0.68 ,  0.665,  0.705,  0.465,  0.54 ,  0.24 ,
#         0.205,  0.21 ,  0.39 ,  0.46 ,  0.325,  0.52 ,  0.4  ,  0.485,
#         0.405,  0.445,  0.245,  0.505,  0.595,  0.31 ,  0.555,  0.57 ,
#         0.6  ,  0.62 ,  0.625,  0.695,  0.36 ,  0.51 ,  0.435,  0.495,
#         0.385,  0.515,  0.37 ,  0.27 ,  0.375,  0.7  ,  0.71 ,  0.265,
#         0.305,  0.345,  0.65 ,  0.28 ,  0.175,  0.17 ,  0.635,  0.645,
#         0.61 ,  0.725,  0.235,  0.315,  0.225,  0.64 ,  0.63 ,  0.585,
#         0.42 ,  0.335,  0.415,  0.275,  0.295,  0.075,  0.13 ,  0.11 ,
#         0.16 ,  0.23 ,  0.3  ,  0.32 ,  0.655,  0.66 ,  0.2  ,  0.165,
#         0.19 ,  0.74 ,  0.34 ,  0.675,  0.745,  0.685,  0.69 ,  0.67 ,
#         0.29 ,  0.26 ,  0.395,  0.41 ,  0.22 ,  0.255,  0.735,  0.155,
#         0.48 ,  0.195,  0.25 ,  0.18 ,  0.15 ,  0.215,  0.73 ,  0.715,
#         0.765,  0.185,  0.285,  0.72 ,  0.75 ,  0.755,  0.78 ,  0.815,
#         0.14 ,  0.77 ,  0.775,  0.76 ,  0.135,  0.8  ])

# %%
print df.ShellWeight.unique()
print df.VisceraWeight.unique()
print df.WholeWeight.unique()
print df.ShuckedWeight.unique()
# Out:
# [ 0.15    0.07    0.21    0.155   0.055   0.12    0.33    0.26    0.165
#   0.32    0.135   0.19    0.205   0.185   0.24    0.115   0.13    0.1
#   0.075   0.085   0.27    0.2     0.305   0.3     0.285   0.28    0.295
#   0.46    0.35    0.455   0.49    0.125   0.34    0.145   0.09    0.02
#   0.012   0.015   0.14    0.045   0.245   0.16    0.11    0.22    0.17
#   0.025   0.175   0.485   0.275   0.425   0.38    0.315   0.345   0.675
#   0.58    0.36    0.44    0.4     0.255   0.39    0.48    0.25    0.335
#   0.235   0.105   0.18    0.31    0.03    0.08    0.54    0.78    0.41
#   0.129   0.062   0.068   0.028   0.1355  0.048   0.063   0.117   0.0925
#   0.2475  0.2665  0.4465  0.2425  0.174   0.1565  0.042   0.0125  0.01
#   0.325   0.45    0.355   0.635   1.005   0.815   0.725   0.85    0.65
#   0.76    0.62    0.59    0.035   0.05    0.57    0.29    0.195   0.465
#   0.23    0.06    0.435   0.04    0.0015  0.004   0.003   0.005   0.37
#   0.365   0.026   0.0905  0.55    0.385   0.585   0.69    0.43    0.225
#   0.375   0.074   0.0715  0.011   0.535   0.265   0.065   0.095   0.71
#   0.395   0.7     0.445   0.47    0.415   0.5     0.6     0.42    0.605
#   0.215   0.505   0.0995  0.008   0.625   0.2185  0.177   0.1045  0.181
#   0.2765  0.2645  0.1345  0.475   0.179   0.0325  0.0885  0.131   0.1135
#   0.049   0.027   0.0155  0.1175  0.168   0.096   0.0345  0.0985  0.1275
#   0.515   0.0835  0.0865  0.166   0.2235  0.154   0.059   0.136   0.081
#   0.1515  0.169   0.1655  0.148   0.152   0.044   0.0195  0.054   0.1335
#   0.1405  0.158   0.53    0.1195  0.0875  0.173   0.123   0.1105  0.144
#   0.0795  0.0765  0.1005  0.032   0.083   0.0335  0.0695  0.0245  0.0085
#   0.293   0.4405  0.525   0.233   0.278   0.2965  0.2905  0.1845  0.262
#   0.1635  0.263   0.1685  0.1625  0.256   0.3635  0.234   0.214   0.122
#   0.2885  0.018   0.023   0.0535  0.0575  0.0745  0.0735  0.0615  0.0605
#   0.086   0.082   0.077   0.094   0.106   0.109   0.091   0.0945  0.1465
#   0.089   0.172   0.1525  0.1775  0.239   0.202   0.2375  0.283   0.2875
#   0.2385  0.2745  0.194   0.2705  0.3095  0.271   0.3205  0.3445  0.3985
#   0.292   0.3685  0.411   0.381   0.406   0.2715  0.321   0.399   0.405
#   0.601   0.453   0.413   0.897   0.0135  0.021   0.017   0.0385  0.043
#   0.037   0.0425  0.0445  0.067   0.1125  0.1145  0.134   0.137   0.119
#   0.1295  0.1265  0.113   0.143   0.1095  0.146   0.127   0.1575  0.1695
#   0.1495  0.1535  0.1825  0.1785  0.156   0.1885  0.1955  0.186   0.2155
#   0.2195  0.218   0.274   0.343   0.249   0.276   0.2835  0.237   0.309
#   0.2515  0.2925  0.3085  0.3295  0.388   0.349   0.401   0.3235  0.3745
#   0.409   0.3185  0.432   0.336   0.3725  0.477   0.403   0.441   0.5175
#   0.4005  0.553   0.498   0.503   0.4045  0.5475  0.4135  0.6205  0.0095
#   0.007   0.0215  0.0225  0.034   0.039   0.0405  0.0635  0.087   0.093
#   0.1035  0.088   0.1315  0.0975  0.098   0.102   0.142   0.1665  0.141
#   0.1585  0.182   0.1385  0.157   0.167   0.254   0.1835  0.201   0.1895
#   0.223   0.2165  0.2215  0.206   0.224   0.2575  0.222   0.238   0.228
#   0.253   0.2295  0.2565  0.317   0.357   0.2415  0.2865  0.267   0.2405
#   0.281   0.332   0.286   0.287   0.3425  0.358   0.3735  0.4245  0.294
#   0.364   0.476   0.3595  0.353   0.4735  0.3865  0.3695  0.4375  0.446
#   0.638   0.3995  0.301   0.4525  0.5075  0.5375  0.5215  0.2685  0.4505
#   0.4825  0.545   0.6785  0.595   0.586   0.0355  0.038   0.052   0.0435
#   0.0525  0.064   0.058   0.061   0.0755  0.0775  0.0655  0.126   0.1245
#   0.114   0.1505  0.132   0.2065  0.196   0.171   0.1905  0.164   0.2045
#   0.192   0.189   0.2075  0.2175  0.229   0.227   0.207   0.2545  0.248
#   0.2325  0.236   0.2695  0.219   0.2655  0.2125  0.306   0.2955  0.204
#   0.2255  0.269   0.3035  0.347   0.2895  0.354   0.3045  0.3365  0.3455
#   0.323   0.3665  0.4075  0.4325  0.391   0.383   0.3925  0.3575  0.469
#   0.461   0.4975  0.512   0.528   0.51    0.5365  0.52    0.565   0.558
#   0.612   0.7975  0.036   0.053   0.0675  0.0825  0.0855  0.0815  0.0805
#   0.073   0.103   0.1075  0.1015  0.1025  0.1065  0.116   0.1365  0.1165
#   0.147   0.198   0.1555  0.161   0.149   0.1735  0.203   0.1945  0.3055
#   0.2095  0.2335  0.288   0.3315  0.251   0.312   0.3465  0.329   0.3245
#   0.377   0.4025  0.495   0.3195  0.444   0.4195  0.4685  0.494   0.5015
#   0.013   0.0415  0.066   0.076   0.0955  0.0965  0.1205  0.112   0.1935
#   0.162   0.138   0.178   0.2135  0.213   0.1725  0.259   0.217   0.231
#   0.2815  0.268   0.2285  0.2535  0.2725  0.2635  0.3345  0.431   0.266
#   0.2945  0.379   0.311   0.313   0.3325  0.3105  0.3145  0.3705  0.339
#   0.328   0.3615  0.418   0.4435  0.386   0.3845  0.378   0.363   0.341
#   0.308   0.4275  0.3545  0.3965  0.4125  0.4705  0.438   0.502   0.566
#   0.511   0.5655  0.557   0.482   0.575   0.63    0.642   0.578   0.0705
#   0.1675  0.1645  0.211   0.1215  0.209   0.2365  0.319   0.2825  0.296
#   0.273   0.252   0.159   0.2105  0.1795  0.304   0.2845  0.344   0.2485
#   0.4155  0.258   0.3285  0.297   0.3005  0.3475  0.291   0.3075  0.466
#   0.389   0.4215  0.4645  0.4425  0.643   0.009   0.1185  0.191   0.184
#   0.1425  0.183   0.1875  0.244   0.279   0.246   0.277   0.2265  0.2795
#   0.242   0.264   0.298   0.352   0.2985  0.3225  0.3885  0.5195  0.3215
#   0.361   0.3535  0.289   0.3395  0.412   0.3255  0.4675  0.3385  0.474
#   0.3305  0.3645  0.497   0.394   0.348   0.436   0.416   0.4115  0.4715
#   0.384   0.538   0.4395  0.501   0.488   0.646   0.006   0.041   0.0495
#   0.046   0.078   0.1375  0.2035  0.1765  0.2675  0.2625  0.0285  0.033
#   0.057   0.0725  0.121   0.139   0.1455  0.2605  0.356   0.3375  0.372
#   0.462   0.479   0.602   0.4935  0.6585  0.885   0.0035  0.5855  0.0935
#   0.665   0.61    0.685   0.216   0.66    0.1815  0.0075  0.069   0.1475
#   0.555   0.022   0.2115  0.3065  0.187   0.163   0.199   0.3175  0.471
#   0.513   0.4065  0.4535  0.6095  0.016   0.0255  0.031   0.0365  0.047
#   0.111   0.1305  0.118   0.1325  0.107   0.1225  0.1485  0.2505  0.3275
#   0.3165  0.3775  0.4175  0.5165  0.624   0.5335  0.584   0.0315  0.1605
#   0.1755  0.2245  0.491   0.2345  0.327   0.176   0.3755  0.351   0.3935
#   0.5085  0.5285  0.0105  0.101   0.1155  0.2305  0.1615  0.1805  0.2435
#   0.2785  0.3265  0.367   0.272   0.307   0.324   0.3115  0.346   0.422
#   0.4865  0.404   0.056   0.0585  0.1115  0.1985  0.1965  0.2595  0.337
#   0.3485  0.4105  0.299   0.331   0.371   0.4755  0.3875  0.4945  0.5315
#   0.0455  0.072   0.1545  0.2525  0.2055  0.208   0.3135  0.3605  0.2775
#   0.398   0.2915  0.2615  0.3525  0.387   0.5305  0.097   0.1975  0.322
#   0.326   0.437   0.563   0.726   0.084   0.079   0.2315  0.4695  0.3825
#   0.3155  0.3015  0.3355  0.3415  0.4485  0.4055  0.4625  0.5965  0.0595
#   0.188   0.221   0.439   0.421   0.0895  0.316   0.3815  0.0185  0.0065
#   0.6855  0.396   0.3805  0.193   0.1595  0.0485  0.212   0.104   0.2495
#   0.0915  0.5235  0.0645  0.151   0.1915  0.4265  0.529   0.014   0.128
#   0.4085  0.449   0.468   0.0305  0.0505  0.0625  0.1855  0.2445  0.374
#   0.302   0.369   0.6195  0.1395  0.333   0.3905  0.4305  0.5675  0.029
#   0.1745  0.2225  0.247   0.3555  0.2935  0.284   0.4355  0.4165  0.4895
#   0.434   0.6745  0.0465  0.1255  0.2455  0.4095  0.407   0.516   0.1435
#   0.2735  0.314   0.342   0.456   0.5295  0.153   0.3945  0.4575  0.4285
#   0.56    0.1085  0.655   0.019   0.133   0.496   0.547   0.5055  0.5755
#   0.621   0.2015  0.4295  0.4545  0.499   0.1415  0.2755  0.3855  0.506
#   0.5385  0.3795  0.2585  0.424   0.508   0.657   0.092 ]
# [  1.01000000e-01   4.85000000e-02   1.41500000e-01   1.14000000e-01
#    3.95000000e-02   7.75000000e-02   1.49500000e-01   1.12500000e-01
#    1.51000000e-01   1.47500000e-01   8.10000000e-02   9.50000000e-02
#    1.71000000e-01   8.05000000e-02   1.33000000e-01   8.70000000e-02
#    4.30000000e-02   7.50000000e-02   6.20000000e-02   4.90000000e-02
#    2.14000000e-01   2.10000000e-01   3.01000000e-01   1.88000000e-01
#    2.72000000e-01   2.34000000e-01   2.19000000e-01   2.27000000e-01
#    2.42000000e-01   2.80500000e-01   3.57500000e-01   3.92500000e-01
#    4.11500000e-01   1.24000000e-01   3.07500000e-01   1.16500000e-01
#    2.03500000e-01   8.60000000e-02   9.10000000e-02   1.96000000e-01
#    2.35000000e-02   1.50000000e-02   1.25000000e-02   4.50000000e-02
#    1.10000000e-01   2.55000000e-02   2.13500000e-01   1.11000000e-01
#    6.00000000e-02   9.60000000e-02   1.05500000e-01   9.15000000e-02
#    1.75500000e-01   9.55000000e-02   1.20000000e-01   1.40000000e-02
#    1.30000000e-01   1.60000000e-01   1.93500000e-01   8.00000000e-02
#    1.31500000e-01   1.01500000e-01   2.24000000e-01   1.15500000e-01
#    4.05000000e-02   1.68000000e-01   9.85000000e-02   2.25000000e-01
#    2.61000000e-01   2.89500000e-01   2.21000000e-01   1.89000000e-01
#    1.94000000e-01   1.59500000e-01   2.35500000e-01   2.52000000e-01
#    1.92000000e-01   2.16000000e-01   2.22500000e-01   2.05000000e-01
#    2.07500000e-01   2.31000000e-01   1.67500000e-01   1.52500000e-01
#    2.54000000e-01   3.18000000e-01   3.42500000e-01   3.88000000e-01
#    1.38500000e-01   1.32000000e-01   8.50000000e-02   4.60000000e-02
#    1.91500000e-01   1.64000000e-01   2.40500000e-01   1.83500000e-01
#    1.83000000e-01   1.79000000e-01   9.80000000e-02   1.34500000e-01
#    1.07000000e-01   6.35000000e-02   6.30000000e-02   1.46000000e-01
#    1.58500000e-01   1.02000000e-01   1.72000000e-01   5.95000000e-02
#    1.03500000e-01   5.75000000e-02   1.72500000e-01   5.10000000e-02
#    5.05000000e-02   5.45000000e-02   6.10000000e-02   2.63500000e-01
#    2.83000000e-01   3.60000000e-02   5.60000000e-02   2.05000000e-02
#    3.45000000e-02   2.95000000e-02   2.05500000e-01   1.43500000e-01
#    3.06000000e-01   1.90000000e-01   1.07500000e-01   1.08000000e-01
#    3.90000000e-02   6.50000000e-03   8.00000000e-03   2.62000000e-01
#    2.58500000e-01   3.05000000e-01   1.31000000e-01   2.42500000e-01
#    2.61500000e-01   1.78500000e-01   2.47500000e-01   2.57500000e-01
#    2.97000000e-01   3.98000000e-01   4.83000000e-01   4.51500000e-01
#    4.08000000e-01   3.08500000e-01   4.09000000e-01   5.41000000e-01
#    1.69000000e-01   2.33000000e-01   1.84500000e-01   1.80000000e-02
#    3.70000000e-02   3.75000000e-02   4.75000000e-02   2.16500000e-01
#    2.00000000e-01   2.66000000e-01   2.68000000e-01   3.67000000e-01
#    2.96500000e-01   3.36000000e-01   3.31500000e-01   3.35000000e-01
#    2.71000000e-01   1.81500000e-01   1.96500000e-01   1.53500000e-01
#    1.45000000e-01   1.78000000e-01   2.13000000e-01   1.46500000e-01
#    1.55000000e-01   7.10000000e-02   1.08500000e-01   6.70000000e-02
#    1.68500000e-01   5.20000000e-02   1.62500000e-01   4.15000000e-02
#    7.85000000e-02   1.35500000e-01   1.28000000e-01   1.63500000e-01
#    7.00000000e-02   1.15000000e-01   7.55000000e-02   1.23500000e-01
#    1.44000000e-01   1.25000000e-01   8.20000000e-02   2.09500000e-01
#    1.58000000e-01   1.93000000e-01   2.87000000e-01   2.90000000e-02
#    8.30000000e-02   3.20000000e-02   5.00000000e-04   3.00000000e-03
#    2.00000000e-03   4.50000000e-03   2.18500000e-01   2.45000000e-02
#    1.05000000e-02   2.65000000e-02   3.25000000e-02   3.80000000e-02
#    3.50000000e-02   2.17000000e-01   2.77500000e-01   2.06500000e-01
#    1.75000000e-01   1.65500000e-01   2.55500000e-01   2.39000000e-01
#    2.80000000e-02   1.86000000e-01   8.85000000e-02   1.00000000e-01
#    2.85500000e-01   2.70500000e-01   2.50500000e-01   3.33500000e-01
#    1.97000000e-01   3.27000000e-01   2.45000000e-01   3.34500000e-01
#    3.11500000e-01   1.60500000e-01   5.70000000e-02   1.04000000e-01
#    1.27000000e-01   1.32500000e-01   8.15000000e-02   1.79500000e-01
#    2.26000000e-01   2.79000000e-01   2.20500000e-01   2.07000000e-01
#    3.40000000e-02   2.85000000e-02   1.27500000e-01   5.85000000e-02
#    8.95000000e-02   1.74000000e-01   4.95000000e-02   9.50000000e-03
#    5.00000000e-03   3.69000000e-01   3.05500000e-01   2.04500000e-01
#    3.23500000e-01   2.70000000e-01   2.94500000e-01   2.20000000e-02
#    4.10000000e-02   5.30000000e-02   1.66500000e-01   4.00000000e-02
#    1.61000000e-01   5.65000000e-02   4.20000000e-02   4.08500000e-01
#    3.17500000e-01   2.65500000e-01   2.76000000e-01   3.25000000e-01
#    2.27500000e-01   2.56500000e-01   3.06500000e-01   1.52000000e-01
#    1.73000000e-01   5.55000000e-02   7.40000000e-02   2.45500000e-01
#    2.90500000e-01   2.59000000e-01   2.86000000e-01   4.90000000e-01
#    3.88500000e-01   4.72000000e-01   3.92000000e-01   2.46000000e-01
#    2.99500000e-01   3.01500000e-01   2.44000000e-01   2.73500000e-01
#    2.76500000e-01   2.99000000e-01   3.45500000e-01   3.26500000e-01
#    4.53000000e-01   3.14000000e-01   2.92000000e-01   3.69500000e-01
#    3.36500000e-01   2.87500000e-01   3.13500000e-01   1.37000000e-01
#    1.22000000e-01   1.24500000e-01   1.22500000e-01   1.19000000e-01
#    5.35000000e-02   6.40000000e-02   1.76000000e-01   1.39000000e-01
#    1.98500000e-01   1.04500000e-01   1.82000000e-01   2.21500000e-01
#    2.11500000e-01   2.38500000e-01   1.71500000e-01   2.46500000e-01
#    2.67000000e-01   3.49000000e-01   1.99000000e-01   3.58000000e-01
#    1.23000000e-01   2.00000000e-02   2.03000000e-01   2.43500000e-01
#    1.73500000e-01   1.29000000e-01   1.70500000e-01   1.56000000e-01
#    9.05000000e-02   4.35000000e-02   5.50000000e-02   6.45000000e-02
#    1.38000000e-01   5.25000000e-02   7.70000000e-02   1.36000000e-01
#    1.57500000e-01   2.32000000e-01   1.59000000e-01   4.72500000e-01
#    3.54000000e-01   2.19500000e-01   3.04500000e-01   1.20000000e-02
#    3.50000000e-03   3.03500000e-01   2.66500000e-01   1.40500000e-01
#    1.45500000e-01   1.39500000e-01   3.40500000e-01   3.21500000e-01
#    2.44500000e-01   1.76500000e-01   2.12000000e-01   2.37000000e-01
#    1.61500000e-01   1.81000000e-01   2.23500000e-01   2.59500000e-01
#    2.09000000e-01   2.31500000e-01   2.02000000e-01   2.14500000e-01
#    2.56000000e-01   2.30500000e-01   2.47000000e-01   1.57000000e-01
#    2.04000000e-01   1.26500000e-01   3.65000000e-02   2.15000000e-02
#    1.95000000e-02   5.90000000e-02   8.50000000e-03   3.85000000e-02
#    4.45000000e-02   6.00000000e-03   2.55000000e-01   6.60000000e-02
#    9.25000000e-02   6.95000000e-02   5.50000000e-03   1.55500000e-01
#    2.00500000e-01   1.95000000e-01   1.41000000e-01   2.98000000e-01
#    2.62500000e-01   9.20000000e-02   1.63000000e-01   1.26000000e-01
#    1.00500000e-01   1.09000000e-01   8.75000000e-02   2.01000000e-01
#    1.97500000e-01   2.49500000e-01   3.43500000e-01   6.50000000e-02
#    1.62000000e-01   1.90500000e-01   7.60000000e-02   5.80000000e-02
#    2.97500000e-01   1.53000000e-01   1.82500000e-01   2.25500000e-01
#    2.24500000e-01   1.13500000e-01   7.95000000e-02   4.55000000e-02
#    1.13000000e-01   6.75000000e-02   8.25000000e-02   3.55000000e-02
#    7.05000000e-02   4.70000000e-02   3.35000000e-02   4.25000000e-02
#    1.09500000e-01   1.16000000e-01   1.85000000e-01   9.45000000e-02
#    1.06500000e-01   5.40000000e-02   1.36500000e-01   8.40000000e-02
#    1.05000000e-01   9.90000000e-02   2.40000000e-02   4.65000000e-02
#    3.44500000e-01   6.15000000e-02   6.65000000e-02   1.40000000e-01
#    2.43000000e-01   1.43000000e-01   1.48000000e-01   2.60000000e-02
#    9.40000000e-02   2.32500000e-01   2.12500000e-01   1.42500000e-01
#    6.55000000e-02   2.50000000e-03   1.14500000e-01   6.85000000e-02
#    1.42000000e-01   1.03000000e-01   9.00000000e-02   2.75000000e-02
#    1.90000000e-02   1.15000000e-02   4.00000000e-03   2.28000000e-01
#    1.19500000e-01   2.01500000e-01   1.69500000e-01   1.80500000e-01
#    2.17500000e-01   1.94500000e-01   4.80500000e-01   4.10500000e-01
#    1.50000000e-01   3.00500000e-01   3.68000000e-01   2.36000000e-01
#    1.67000000e-01   3.61000000e-01   2.96000000e-01   5.00000000e-02
#    2.39500000e-01   2.81500000e-01   1.70000000e-01   1.50500000e-01
#    1.37500000e-01   2.06000000e-01   1.65000000e-02   2.02500000e-01
#    1.28500000e-01   2.60000000e-01   1.17000000e-01   9.35000000e-02
#    3.00000000e-02   2.10000000e-02   4.80000000e-02   1.18500000e-01
#    1.85500000e-01   2.40000000e-01   2.15500000e-01   3.30000000e-01
#    2.60500000e-01   2.75000000e-01   2.54500000e-01   2.85000000e-01
#    2.75500000e-01   3.32000000e-01   3.15000000e-01   2.91000000e-01
#    3.41500000e-01   3.91000000e-01   3.22000000e-01   3.77500000e-01
#    4.22000000e-01   4.19000000e-01   1.35000000e-02   2.50000000e-02
#    3.10000000e-02   3.05000000e-02   4.40000000e-02   6.90000000e-02
#    7.45000000e-02   7.20000000e-02   7.80000000e-02   8.35000000e-02
#    9.30000000e-02   8.55000000e-02   1.06000000e-01   1.21500000e-01
#    1.29500000e-01   1.20500000e-01   1.34000000e-01   2.29000000e-01
#    2.74500000e-01   2.20000000e-01   2.64500000e-01   2.58000000e-01
#    2.78000000e-01   3.02000000e-01   2.84000000e-01   2.48000000e-01
#    3.00000000e-01   3.26000000e-01   3.42000000e-01   3.55500000e-01
#    3.08000000e-01   3.12000000e-01   3.22500000e-01   3.31000000e-01
#    3.02500000e-01   3.59500000e-01   2.94000000e-01   3.14500000e-01
#    3.61500000e-01   3.62000000e-01   4.01500000e-01   3.96000000e-01
#    4.20000000e-01   5.22500000e-01   4.18500000e-01   3.83000000e-01
#    4.40000000e-01   5.09000000e-01   7.50000000e-03   9.00000000e-03
#    1.30000000e-02   1.55000000e-02   1.75000000e-02   2.70000000e-02
#    8.65000000e-02   7.35000000e-02   1.12000000e-01   1.49000000e-01
#    1.77500000e-01   1.88500000e-01   2.37500000e-01   1.91000000e-01
#    4.26000000e-01   2.57000000e-01   2.36500000e-01   2.50000000e-01
#    2.71500000e-01   2.90000000e-01   2.11000000e-01   3.39000000e-01
#    3.72500000e-01   3.65500000e-01   3.68500000e-01   3.10500000e-01
#    4.05000000e-01   3.48500000e-01   3.71500000e-01   3.35500000e-01
#    4.18000000e-01   3.07000000e-01   3.81000000e-01   4.07000000e-01
#    3.13000000e-01   4.80000000e-01   4.69000000e-01   4.25500000e-01
#    3.80000000e-01   5.50000000e-01   4.58500000e-01   5.19500000e-01
#    5.13000000e-01   4.98500000e-01   3.30000000e-02   6.25000000e-02
#    6.05000000e-02   7.15000000e-02   8.90000000e-02   7.30000000e-02
#    1.25500000e-01   1.21000000e-01   1.35000000e-01   1.44500000e-01
#    1.54500000e-01   1.65000000e-01   1.30500000e-01   1.84000000e-01
#    2.52500000e-01   1.47000000e-01   2.73000000e-01   2.53500000e-01
#    2.34500000e-01   1.74500000e-01   2.33500000e-01   1.95500000e-01
#    3.19500000e-01   2.68500000e-01   3.45000000e-01   2.95000000e-01
#    1.86500000e-01   2.72500000e-01   2.69500000e-01   3.72000000e-01
#    3.51500000e-01   2.74000000e-01   3.78000000e-01   3.58500000e-01
#    3.73500000e-01   3.86500000e-01   3.52500000e-01   3.12500000e-01
#    4.87000000e-01   4.16000000e-01   3.99000000e-01   3.74000000e-01
#    4.86500000e-01   4.19500000e-01   3.89000000e-01   5.64000000e-01
#    4.34500000e-01   4.60000000e-01   4.46000000e-01   5.19000000e-01
#    1.45000000e-02   9.95000000e-02   1.10500000e-01   1.02500000e-01
#    1.56500000e-01   2.18000000e-01   2.30000000e-01   2.15000000e-01
#    2.08500000e-01   2.35000000e-01   3.24500000e-01   3.65000000e-01
#    3.04000000e-01   4.09500000e-01   3.51000000e-01   3.24000000e-01
#    4.47500000e-01   3.25500000e-01   3.32500000e-01   3.66500000e-01
#    3.63000000e-01   4.13000000e-01   4.27000000e-01   3.97000000e-01
#    1.10000000e-02   1.70000000e-02   3.15000000e-02   1.17500000e-01
#    1.48500000e-01   1.87000000e-01   1.66000000e-01   2.38000000e-01
#    1.98000000e-01   1.51500000e-01   1.92500000e-01   2.41000000e-01
#    2.26500000e-01   2.64000000e-01   2.51500000e-01   2.91500000e-01
#    2.23000000e-01   2.86500000e-01   3.09000000e-01   2.92500000e-01
#    4.20500000e-01   2.88000000e-01   3.37000000e-01   2.81000000e-01
#    3.80500000e-01   2.69000000e-01   3.29500000e-01   3.54500000e-01
#    3.84500000e-01   2.53000000e-01   3.20000000e-01   3.11000000e-01
#    3.09500000e-01   3.30500000e-01   2.93000000e-01   3.75000000e-01
#    3.67500000e-01   3.93500000e-01   4.56500000e-01   4.92500000e-01
#    4.54000000e-01   3.66000000e-01   4.42500000e-01   4.03000000e-01
#    5.18500000e-01   4.82500000e-01   4.21000000e-01   6.41500000e-01
#    7.60000000e-01   2.29500000e-01   2.78500000e-01   3.33000000e-01
#    4.36000000e-01   4.26500000e-01   9.65000000e-02   9.75000000e-02
#    1.33500000e-01   1.64500000e-01   2.28500000e-01   2.88500000e-01
#    2.82500000e-01   3.46000000e-01   4.40500000e-01   3.46500000e-01
#    3.84000000e-01   2.48500000e-01   3.03000000e-01   2.95500000e-01
#    2.67500000e-01   2.84500000e-01   3.79000000e-01   4.02000000e-01
#    3.83500000e-01   4.47000000e-01   2.98500000e-01   3.47000000e-01
#    3.60500000e-01   4.30500000e-01   4.91500000e-01   1.85000000e-02
#    2.30000000e-02   6.80000000e-02   1.54000000e-01   1.77000000e-01
#    3.53000000e-01   2.25000000e-02   1.89500000e-01   3.39500000e-01
#    3.87000000e-01   3.97500000e-01   4.48000000e-01   4.75500000e-01
#    2.65000000e-01   2.10500000e-01   3.70500000e-01   1.00000000e-02
#    7.25000000e-02   2.77000000e-01   7.65000000e-02   8.45000000e-02
#    4.37000000e-01   3.28500000e-01   4.65000000e-01   4.92000000e-01
#    4.07500000e-01   3.60000000e-01   3.76500000e-01   2.83500000e-01
#    3.48000000e-01   5.90000000e-01   1.87500000e-01   4.35000000e-01
#    4.23000000e-01   2.08000000e-01   3.43000000e-01   1.18000000e-01
#    1.80000000e-01   3.71000000e-01   1.11500000e-01   2.63000000e-01
#    3.23000000e-01   3.17000000e-01   3.75500000e-01   4.29000000e-01
#    3.85500000e-01   4.42000000e-01   5.00500000e-01   5.12000000e-01
#    4.82000000e-01   1.99500000e-01   3.52000000e-01   5.26500000e-01
#    5.23500000e-01   8.80000000e-02   9.70000000e-02   4.36500000e-01
#    2.22000000e-01   2.82000000e-01   3.77000000e-01   3.37500000e-01
#    3.73000000e-01   4.17000000e-01   3.21000000e-01   5.25000000e-01
#    1.60000000e-02   3.15500000e-01   2.89000000e-01   4.63000000e-01
#    5.11500000e-01   5.15000000e-02   3.19000000e-01   4.05500000e-01
#    4.65500000e-01   4.78000000e-01   4.74000000e-01   3.90500000e-01
#    4.03500000e-01   3.16500000e-01   3.34000000e-01   4.28500000e-01
#    4.57500000e-01   3.56500000e-01   3.79500000e-01   3.57000000e-01
#    7.00000000e-03   4.06500000e-01   3.98500000e-01   3.20500000e-01
#    3.28000000e-01   4.00500000e-01   4.39500000e-01   2.80000000e-01
#    2.41500000e-01   4.87500000e-01   7.90000000e-02   4.50500000e-01
#    3.41000000e-01   5.75000000e-01   3.85000000e-01   3.64500000e-01
#    3.96500000e-01   3.27500000e-01   4.43500000e-01   4.01000000e-01
#    3.50500000e-01   5.14500000e-01   2.79500000e-01   4.10000000e-01
#    3.94000000e-01   5.74500000e-01   4.02500000e-01   4.21500000e-01
#    4.69500000e-01   3.95000000e-01   3.38500000e-01   3.86000000e-01
#    3.50000000e-01   4.66500000e-01   3.82000000e-01   4.04500000e-01
#    4.11000000e-01   2.49000000e-01   3.64000000e-01   4.38500000e-01
#    3.53500000e-01   4.22500000e-01   2.93500000e-01   5.26000000e-01]
# [ 0.514   0.2255  0.677  ...,  1.176   1.0945  1.9485]
# [ 0.2245  0.0995  0.2565 ...,  0.727   0.137   0.9455]

# %%
df.Sex.unique()
# Out:
# array(['M', 'F', 'I'], dtype=object)

# %%
df.Sex.value_counts()
# Out:
# M    1528
# I    1340
# F    1307
# Name: Sex, dtype: int64

# %%
#Separate Sex values to adult/non-adult
isAdult = df.Sex.apply(lambda value: 0 if 'I' in value else 1)
df.append(isAdult)
df = df.copy()
df['isAdult'] = isAdult
#merge(df, isAdult, on='key')
#df[['isAdult']] = df[['Sex']].apply(lambda value: value if 'I' in value else 'A')

# df[ ['RingsLog'] ] = df[ ['Rings'] ].apply(np.log)

df
# Out:
#      Sex  Length  Diameter  Height  WholeWeight  ShuckedWeight  VisceraWeight  \
# 0      M   0.455     0.365   0.095       0.5140         0.2245         0.1010
# 1      M   0.350     0.265   0.090       0.2255         0.0995         0.0485
# 2      F   0.530     0.420   0.135       0.6770         0.2565         0.1415
# 3      M   0.440     0.365   0.125       0.5160         0.2155         0.1140
# 4      I   0.330     0.255   0.080       0.2050         0.0895         0.0395
# ...   ..     ...       ...     ...          ...            ...            ...
# 4172   F   0.565     0.450   0.165       0.8870         0.3700         0.2390
# 4173   M   0.590     0.440   0.135       0.9660         0.4390         0.2145
# 4174   M   0.600     0.475   0.205       1.1760         0.5255         0.2875
# 4175   F   0.625     0.485   0.150       1.0945         0.5310         0.2610
# 4176   M   0.710     0.555   0.195       1.9485         0.9455         0.3765
#
#       ShellWeight  Rings  isAdult
# 0          0.1500     15        1
# 1          0.0700      7        1
# 2          0.2100      9        1
# 3          0.1550     10        1
# 4          0.0550      7        0
# ...           ...    ...      ...
# 4172       0.2490     11        1
# 4173       0.2605     10        1
# 4174       0.3080      9        1
# 4175       0.2960     10        1
# 4176       0.4950     12        1
#
# [4175 rows x 10 columns]

# %%
df.corr()
# Out:
#                  Length  Diameter    Height  WholeWeight  ShuckedWeight  \
# Length         1.000000  0.986802  0.828108     0.925217       0.897859
# Diameter       0.986802  1.000000  0.834298     0.925414       0.893108
# Height         0.828108  0.834298  1.000000     0.819886       0.775621
# WholeWeight    0.925217  0.925414  0.819886     1.000000       0.969389
# ShuckedWeight  0.897859  0.893108  0.775621     0.969389       1.000000
# VisceraWeight  0.902960  0.899672  0.798908     0.966354       0.931924
# ShellWeight    0.898419  0.906084  0.819596     0.955924       0.883129
# Rings          0.556464  0.574418  0.557625     0.540151       0.420597
# isAdult        0.551106  0.563987  0.517873     0.557275       0.521538
#
#                VisceraWeight  ShellWeight     Rings   isAdult
# Length              0.902960     0.898419  0.556464  0.551106
# Diameter            0.899672     0.906084  0.574418  0.563987
# Height              0.798908     0.819596  0.557625  0.517873
# WholeWeight         0.966354     0.955924  0.540151  0.557275
# ShuckedWeight       0.931924     0.883129  0.420597  0.521538
# VisceraWeight       1.000000     0.908186  0.503562  0.555756
# ShellWeight         0.908186     1.000000  0.627928  0.547294
# Rings               0.503562     0.627928  1.000000  0.435747
# isAdult             0.555756     0.547294  0.435747  1.000000

# %%
df.columns
# Out:
# Index([u'Sex', u'Length', u'Diameter', u'Height', u'WholeWeight',
#        u'ShuckedWeight', u'VisceraWeight', u'ShellWeight', u'Rings',
#        u'isAdult'],
#       dtype='object')

# %%
df
# Out:
#      Sex  Length  Diameter  Height  WholeWeight  ShuckedWeight  VisceraWeight  \
# 0      M   0.455     0.365   0.095       0.5140         0.2245         0.1010
# 1      M   0.350     0.265   0.090       0.2255         0.0995         0.0485
# 2      F   0.530     0.420   0.135       0.6770         0.2565         0.1415
# 3      M   0.440     0.365   0.125       0.5160         0.2155         0.1140
# 4      I   0.330     0.255   0.080       0.2050         0.0895         0.0395
# ...   ..     ...       ...     ...          ...            ...            ...
# 4172   F   0.565     0.450   0.165       0.8870         0.3700         0.2390
# 4173   M   0.590     0.440   0.135       0.9660         0.4390         0.2145
# 4174   M   0.600     0.475   0.205       1.1760         0.5255         0.2875
# 4175   F   0.625     0.485   0.150       1.0945         0.5310         0.2610
# 4176   M   0.710     0.555   0.195       1.9485         0.9455         0.3765
#
#       ShellWeight  Rings  isAdult
# 0          0.1500     15        1
# 1          0.0700      7        1
# 2          0.2100      9        1
# 3          0.1550     10        1
# 4          0.0550      7        0
# ...           ...    ...      ...
# 4172       0.2490     11        1
# 4173       0.2605     10        1
# 4174       0.3080      9        1
# 4175       0.2960     10        1
# 4176       0.4950     12        1
#
# [4175 rows x 10 columns]

# %% [markdown]
# ## Plot the Data

# %%
#df.SexNum = df.StationType.apply(lambda value: 'C' if "Davis" in value else value)

# %%
dfSex = df.groupby(['Rings', 'Sex']).size()
dfSex=dfSex.unstack()
dfSex.plot(kind='bar', figsize = (12, 8))

# %%
dfSex = df.groupby(['Rings', 'isAdult']).size()
dfSex=dfSex.unstack()
dfSex.plot(kind='bar', figsize = (12, 8))

# %%
df.boxplot('Rings', by = 'Sex')

# %%
df.boxplot('Rings', by = 'isAdult')

# %%
#dfCheckSex = df[df.Sex == 'I' and df.Rings > 20].any()
#dfCheckSex
# def blah(df):
#     if df.Sex == 'I' and df.Rings > 20:
#         dfSexCheck = df
# blah(df)
# dfSexCheck

# %%
df[ ['isAdult', 'Length'] ].plot(kind = 'scatter', x = 'Length', y = 'isAdult', s = 100, figsize = (8, 8))

# %%
#df[ ['isAdult', 'VolumeLog'] ].plot(kind = 'scatter', x = 'VolumeLog', y = 'isAdult', s = 100, figsize = (8, 8))

# %%
df[ ['Rings', 'ShellWeight'] ].plot(kind = 'scatter', x = 'ShellWeight', y = 'Rings', s = 100, figsize = (8, 8))

# %%
df[ ['Rings', 'VisceraWeight'] ].plot(kind = 'scatter', x = 'VisceraWeight', y = 'Rings', s = 100, figsize = (8, 8))

# %%
df[ ['Rings', 'ShuckedWeight'] ].plot(kind = 'scatter', x = 'ShuckedWeight', y = 'Rings', s = 100, figsize = (8, 8))

# %%
df[ ['Rings', 'WholeWeight'] ].plot(kind = 'scatter', x = 'WholeWeight', y = 'Rings', s = 100, figsize = (8, 8))

# %%
df[ ['Rings', 'Height'] ].plot(kind = 'scatter', x = 'Height', y = 'Rings', s = 100, figsize = (8, 8))

# %%
sns.lmplot('Height', 'Rings', df)

# %%
df[ ['Rings', 'Diameter'] ].plot(kind = 'scatter', x = 'Diameter', y = 'Rings', s = 100, figsize = (8, 8))

# %%
sns.lmplot('Diameter', 'Rings', df)

# %%
df[ ['Rings', 'Length'] ].plot(kind = 'scatter', x = 'Length', y = 'Rings', s = 100, figsize = (8, 8))

# %%
sns.lmplot('Length', 'Rings', df)

# %%
def transform_variables(df):
    df.Volume = df.Length * df.Diameter * df.Height
    df.VolumeCube = df.Volume ** 1/3

transform_variables(df)
dfV = df.Volume
dfVC = df.VolumeCube

# %%
dfVC
# Out:
# 0       0.005259
# 1       0.002782
# 2       0.010017
# 3       0.006692
# 4       0.002244
#           ...
# 4172    0.013984
# 4173    0.011682
# 4174    0.019475
# 4175    0.015156
# 4176    0.025613
# dtype: float64

# %%
# Add volume column onto df
df = df.copy()
df['Volume'] = dfV
df['VolumeCubed'] = dfV

df[ ['VolumeLog'] ] = df[ ['Volume'] ].apply(np.log)
df[ ['RingsLog'] ] = df[ ['Rings'] ].apply(np.log)
df[ ['ShellWeightLog'] ] = df[ ['ShellWeight'] ].apply(np.log)
df[ ['ShuckedWeightLog'] ] = df[ ['ShuckedWeight'] ].apply(np.log)

df
# Out:
#      Sex  Length  Diameter  Height  WholeWeight        ...         \
# 0      M   0.455     0.365   0.095       0.5140        ...
# 1      M   0.350     0.265   0.090       0.2255        ...
# 2      F   0.530     0.420   0.135       0.6770        ...
# 3      M   0.440     0.365   0.125       0.5160        ...
# 4      I   0.330     0.255   0.080       0.2050        ...
# ...   ..     ...       ...     ...          ...        ...
# 4172   F   0.565     0.450   0.165       0.8870        ...
# 4173   M   0.590     0.440   0.135       0.9660        ...
# 4174   M   0.600     0.475   0.205       1.1760        ...
# 4175   F   0.625     0.485   0.150       1.0945        ...
# 4176   M   0.710     0.555   0.195       1.9485        ...
#
#       VolumeCubed  VolumeLog  RingsLog  ShellWeightLog  ShuckedWeightLog
# 0        0.015777  -4.149194  2.708050       -1.897120         -1.493880
# 1        0.008347  -4.785793  1.945910       -2.659260         -2.307598
# 2        0.030051  -3.504859  2.197225       -1.560648         -1.360627
# 3        0.020075  -3.908280  2.302585       -1.864330         -1.534794
# 4        0.006732  -5.000883  1.945910       -2.900422         -2.413517
# ...           ...        ...       ...             ...               ...
# 4172     0.041951  -3.171247  2.397895       -1.390302         -0.994252
# 4173     0.035046  -3.351094  2.302585       -1.345152         -0.823256
# 4174     0.058425  -2.840011  2.197225       -1.177655         -0.643405
# 4175     0.045469  -3.090730  2.302585       -1.217396         -0.632993
# 4176     0.076840  -2.566033  2.484907       -0.703198         -0.056041
#
# [4175 rows x 16 columns]

# %%
df['ShellShuckedWeight'] = df['ShellWeight'] + df['ShuckedWeight']
df
# Out:
#      Sex  Length  Diameter  Height  WholeWeight         ...          \
# 0      M   0.455     0.365   0.095       0.5140         ...
# 1      M   0.350     0.265   0.090       0.2255         ...
# 2      F   0.530     0.420   0.135       0.6770         ...
# 3      M   0.440     0.365   0.125       0.5160         ...
# 4      I   0.330     0.255   0.080       0.2050         ...
# ...   ..     ...       ...     ...          ...         ...
# 4172   F   0.565     0.450   0.165       0.8870         ...
# 4173   M   0.590     0.440   0.135       0.9660         ...
# 4174   M   0.600     0.475   0.205       1.1760         ...
# 4175   F   0.625     0.485   0.150       1.0945         ...
# 4176   M   0.710     0.555   0.195       1.9485         ...
#
#       VolumeLog  RingsLog  ShellWeightLog  ShuckedWeightLog  \
# 0     -4.149194  2.708050       -1.897120         -1.493880
# 1     -4.785793  1.945910       -2.659260         -2.307598
# 2     -3.504859  2.197225       -1.560648         -1.360627
# 3     -3.908280  2.302585       -1.864330         -1.534794
# 4     -5.000883  1.945910       -2.900422         -2.413517
# ...         ...       ...             ...               ...
# 4172  -3.171247  2.397895       -1.390302         -0.994252
# 4173  -3.351094  2.302585       -1.345152         -0.823256
# 4174  -2.840011  2.197225       -1.177655         -0.643405
# 4175  -3.090730  2.302585       -1.217396         -0.632993
# 4176  -2.566033  2.484907       -0.703198         -0.056041
#
#       ShellShuckedWeight
# 0                 0.3745
# 1                 0.1695
# 2                 0.4665
# 3                 0.3705
# 4                 0.1445
# ...                  ...
# 4172              0.6190
# 4173              0.6995
# 4174              0.8335
# 4175              0.8270
# 4176              1.4405
#
# [4175 rows x 17 columns]

# %%
df[ ['Rings', 'Volume'] ].plot(kind = 'scatter', x = 'Volume', y = 'Rings', s = 100, figsize = (8, 8))

# %%
df[ ['RingsLog', 'VolumeLog'] ].plot(kind = 'scatter', x = 'VolumeLog', y = 'RingsLog', s = 100, figsize = (8, 8))

# %%
sns.lmplot('VolumeLog', 'RingsLog', df)

# %%
sns.lmplot('Volume', 'Rings', df)

# %%
df[ ['Rings', 'VolumeLog'] ].plot(kind = 'scatter', x = 'VolumeLog', y = 'Rings', s = 100, figsize = (8, 8))

# %%
df[ ['Rings', 'VolumeCubed'] ].plot(kind = 'scatter', x = 'VolumeCubed', y = 'Rings', s = 100, figsize = (8, 8))

# %% [markdown]
# ## Models

# %%
df.columns
# Out:
# Index([u'Sex', u'Length', u'Diameter', u'Height', u'WholeWeight',
#        u'ShuckedWeight', u'VisceraWeight', u'ShellWeight', u'Rings',
#        u'isAdult', u'Volume', u'VolumeCubed', u'VolumeLog', u'RingsLog',
#        u'ShellWeightLog', u'ShuckedWeightLog', u'ShellShuckedWeight'],
#       dtype='object')

# %%
model_1 = smf.ols(formula = 'Rings ~ 0 + isAdult + Length * Diameter * Height * ShuckedWeight', data = df).fit().summary()
model_1
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rings   R-squared:                       0.948
# Model:                            OLS   Adj. R-squared:                  0.947
# Method:                 Least Squares   F-statistic:                     4694.
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:18   Log-Likelihood:                -9566.3
# No. Observations:                4175   AIC:                         1.916e+04
# Df Residuals:                    4159   BIC:                         1.927e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------------------
# isAdult                                  1.1229      0.099     11.323      0.000         0.928     1.317
# Length                                  12.0795     13.465      0.897      0.370       -14.318    38.477
# Diameter                                24.3676     19.102      1.276      0.202       -13.082    61.817
# Length:Diameter                        -77.0238     13.591     -5.667      0.000      -103.670   -50.378
# Height                                 -76.8912     19.584     -3.926      0.000      -115.285   -38.497
# Length:Height                          163.4126    112.038      1.459      0.145       -56.242   383.067
# Diameter:Height                        339.3251    151.347      2.242      0.025        42.603   636.047
# Length:Diameter:Height                -246.1161     69.870     -3.522      0.000      -383.099  -109.133
# ShuckedWeight                           44.8503     16.642      2.695      0.007        12.223    77.478
# Length:ShuckedWeight                   -42.0080     50.982     -0.824      0.410      -141.960    57.944
# Diameter:ShuckedWeight                 -91.5047     67.997     -1.346      0.178      -224.815    41.805
# Length:Diameter:ShuckedWeight          128.7619     65.382      1.969      0.049         0.579   256.945
# Height:ShuckedWeight                  -670.2696    119.852     -5.592      0.000      -905.244  -435.295
# Length:Height:ShuckedWeight            661.9204    286.708      2.309      0.021        99.819  1224.022
# Diameter:Height:ShuckedWeight          937.7494    380.475      2.465      0.014       191.814  1683.685
# Length:Diameter:Height:ShuckedWeight -1106.0423    361.575     -3.059      0.002     -1814.923  -397.161
# ==============================================================================
# Omnibus:                     1229.137   Durbin-Watson:                   1.317
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3935.410
# Skew:                           1.490   Prob(JB):                         0.00
# Kurtosis:                       6.707   Cond. No.                     1.62e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.62e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model_2 = smf.ols(formula = 'Rings ~ 0 + isAdult + Length * Diameter * Height * WholeWeight', data = df).fit().summary()
model_2
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rings   R-squared:                       0.942
# Model:                            OLS   Adj. R-squared:                  0.942
# Method:                 Least Squares   F-statistic:                     4231.
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:18   Log-Likelihood:                -9770.9
# No. Observations:                4175   AIC:                         1.957e+04
# Df Residuals:                    4159   BIC:                         1.968e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------------
# isAdult                                0.8995      0.107      8.445      0.000         0.691     1.108
# Length                                 8.9301     15.001      0.595      0.552       -20.479    38.340
# Diameter                              43.2980     21.409      2.022      0.043         1.324    85.272
# Length:Diameter                     -107.7606     18.065     -5.965      0.000      -143.177   -72.345
# Height                               -89.6886     21.927     -4.090      0.000      -132.676   -46.701
# Length:Height                        169.6861    135.457      1.253      0.210       -95.883   435.255
# Diameter:Height                      166.1017    184.455      0.901      0.368      -195.528   527.731
# Length:Diameter:Height               -39.8675     94.286     -0.423      0.672      -224.718   144.983
# WholeWeight                           34.3692     11.454      3.001      0.003        11.913    56.825
# Length:WholeWeight                   -33.9218     27.791     -1.221      0.222       -88.407    20.564
# Diameter:WholeWeight                 -69.1088     36.741     -1.881      0.060      -141.141     2.924
# Length:Diameter:WholeWeight           98.8120     39.383      2.509      0.012        21.600   176.024
# Height:WholeWeight                  -156.9821     77.361     -2.029      0.043      -308.652    -5.313
# Length:Height:WholeWeight             88.6596    154.898      0.572      0.567      -215.023   392.342
# Diameter:Height:WholeWeight          360.6991    194.324      1.856      0.064       -20.281   741.679
# Length:Diameter:Height:WholeWeight  -393.1056    209.115     -1.880      0.060      -803.083    16.871
# ==============================================================================
# Omnibus:                     1272.482   Durbin-Watson:                   1.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4192.369
# Skew:                           1.534   Prob(JB):                         0.00
# Kurtosis:                       6.833   Cond. No.                     1.23e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.23e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model_3 = smf.ols(formula = 'Rings ~ 0 + Length * Diameter * Height + VisceraWeight', data = df).fit().summary()
model_3
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rings   R-squared:                       0.940
# Model:                            OLS   Adj. R-squared:                  0.939
# Method:                 Least Squares   F-statistic:                     8095.
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:18   Log-Likelihood:                -9862.0
# No. Observations:                4175   AIC:                         1.974e+04
# Df Residuals:                    4167   BIC:                         1.979e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------
# Length                     7.8099      8.529      0.916      0.360        -8.911    24.531
# Diameter                  29.4982     11.783      2.504      0.012         6.398    52.598
# Length:Diameter          -42.0711      6.334     -6.642      0.000       -54.490   -29.652
# Height                   -29.4859     11.487     -2.567      0.010       -52.006    -6.966
# Length:Height              3.6925     56.855      0.065      0.948      -107.774   115.159
# Diameter:Height          148.9777     79.363      1.877      0.061        -6.617   304.572
# Length:Diameter:Height   -55.5929     28.554     -1.947      0.052      -111.574     0.388
# VisceraWeight              0.3285      1.151      0.285      0.775        -1.928     2.585
# ==============================================================================
# Omnibus:                     1308.925   Durbin-Watson:                   1.041
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5031.590
# Skew:                           1.517   Prob(JB):                         0.00
# Kurtosis:                       7.441   Cond. No.                     1.88e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.88e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model_4 = smf.ols(formula = 'Rings ~ 0 + Length * Diameter * Height * ShellWeight', data = df).fit().summary()
model_4
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rings   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.951
# Method:                 Least Squares   F-statistic:                     5428.
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:18   Log-Likelihood:                -9406.7
# No. Observations:                4175   AIC:                         1.884e+04
# Df Residuals:                    4160   BIC:                         1.894e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------------
# Length                                 7.8250     13.482      0.580      0.562       -18.607    34.257
# Diameter                              26.5086     19.410      1.366      0.172       -11.546    64.564
# Length:Diameter                      -54.4149     15.140     -3.594      0.000       -84.097   -24.733
# Height                                18.5516     20.279      0.915      0.360       -21.206    58.309
# Length:Height                       -113.2063    121.483     -0.932      0.351      -351.377   124.965
# Diameter:Height                      -52.9043    164.097     -0.322      0.747      -374.621   268.813
# Length:Diameter:Height               295.1808     74.370      3.969      0.000       149.376   440.986
# ShellWeight                           71.0358     35.860      1.981      0.048         0.731   141.341
# Length:ShellWeight                    -6.1953     89.288     -0.069      0.945      -181.248   168.858
# Diameter:ShellWeight                -175.3986    114.074     -1.538      0.124      -399.045    48.248
# Length:Diameter:ShellWeight          152.6691    115.998      1.316      0.188       -74.749   380.088
# Height:ShellWeight                   432.3726    249.551      1.733      0.083       -56.881   921.626
# Length:Height:ShellWeight           -906.7916    505.758     -1.793      0.073     -1898.348    84.765
# Diameter:Height:ShellWeight         -128.6507    611.207     -0.210      0.833     -1326.944  1069.643
# Length:Diameter:Height:ShellWeight   554.2288    648.759      0.854      0.393      -717.685  1826.142
# ==============================================================================
# Omnibus:                     1103.952   Durbin-Watson:                   1.205
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3741.060
# Skew:                           1.311   Prob(JB):                         0.00
# Kurtosis:                       6.826   Cond. No.                     2.08e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.08e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model_5 = smf.ols(formula = 'Rings ~ 0 + Volume * ShellWeight', data = df).fit().summary()
model_5
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rings   R-squared:                       0.916
# Model:                            OLS   Adj. R-squared:                  0.916
# Method:                 Least Squares   F-statistic:                 1.519e+04
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:18   Log-Likelihood:                -10546.
# No. Observations:                4175   AIC:                         2.110e+04
# Df Residuals:                    4172   BIC:                         2.112e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# Volume                78.1227      6.730     11.609      0.000        64.929    91.316
# ShellWeight           51.4511      0.966     53.244      0.000        49.557    53.346
# Volume:ShellWeight  -514.4893      8.709    -59.072      0.000      -531.564  -497.414
# ==============================================================================
# Omnibus:                      387.775   Durbin-Watson:                   0.813
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              621.854
# Skew:                           0.684   Prob(JB):                    9.25e-136
# Kurtosis:                       4.306   Cond. No.                         54.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model_6 = smf.ols(formula = 'Rings ~ 0 + VolumeCubed * ShellWeight', data = df).fit().summary()
model_6
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rings   R-squared:                       0.916
# Model:                            OLS   Adj. R-squared:                  0.916
# Method:                 Least Squares   F-statistic:                 1.519e+04
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:18   Log-Likelihood:                -10546.
# No. Observations:                4175   AIC:                         2.110e+04
# Df Residuals:                    4172   BIC:                         2.112e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------------
# VolumeCubed                78.1227      6.730     11.609      0.000        64.929    91.316
# ShellWeight                51.4511      0.966     53.244      0.000        49.557    53.346
# VolumeCubed:ShellWeight  -514.4893      8.709    -59.072      0.000      -531.564  -497.414
# ==============================================================================
# Omnibus:                      387.775   Durbin-Watson:                   0.813
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              621.854
# Skew:                           0.684   Prob(JB):                    9.25e-136
# Kurtosis:                       4.306   Cond. No.                         54.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model_6 = smf.ols(formula = 'Rings ~ 0 + Height * WholeWeight', data = df).fit().summary()
model_6
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rings   R-squared:                       0.935
# Model:                            OLS   Adj. R-squared:                  0.935
# Method:                 Least Squares   F-statistic:                 1.986e+04
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:18   Log-Likelihood:                -10027.
# No. Observations:                4175   AIC:                         2.006e+04
# Df Residuals:                    4172   BIC:                         2.008e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# Height                62.5483      0.916     68.249      0.000        60.751    64.345
# WholeWeight            7.4577      0.315     23.713      0.000         6.841     8.074
# Height:WholeWeight   -38.4468      1.410    -27.265      0.000       -41.211   -35.682
# ==============================================================================
# Omnibus:                     1076.596   Durbin-Watson:                   1.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            47426.893
# Skew:                           0.448   Prob(JB):                         0.00
# Kurtosis:                      19.487   Cond. No.                         35.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model_7 = smf.ols(formula = 'Rings ~ 0 + Length + Height + Diameter + ShuckedWeight', data = df).fit().summary()
model_7
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rings   R-squared:                       0.943
# Model:                            OLS   Adj. R-squared:                  0.943
# Method:                 Least Squares   F-statistic:                 1.720e+04
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:18   Log-Likelihood:                -9744.4
# No. Observations:                4175   AIC:                         1.950e+04
# Df Residuals:                    4171   BIC:                         1.952e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Length           -6.1655      1.840     -3.350      0.001        -9.774    -2.557
# Height           23.7034      1.692     14.006      0.000        20.385    27.021
# Diameter         29.8036      2.444     12.196      0.000        25.013    34.595
# ShuckedWeight    -6.3585      0.269    -23.673      0.000        -6.885    -5.832
# ==============================================================================
# Omnibus:                     1289.512   Durbin-Watson:                   1.151
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7288.116
# Skew:                           1.356   Prob(JB):                         0.00
# Kurtosis:                       8.877   Cond. No.                         63.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model_8 = smf.ols(formula = 'Rings ~ 0 + Length + Height + Diameter + WholeWeight', data = df).fit().summary()
model_8
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rings   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                 1.559e+04
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:18   Log-Likelihood:                -9938.3
# No. Observations:                4175   AIC:                         1.988e+04
# Df Residuals:                    4171   BIC:                         1.991e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Length         -4.2776      1.953     -2.190      0.029        -8.106    -0.449
# Height         22.8071      1.790     12.744      0.000        19.299    26.316
# Diameter       25.2342      2.601      9.701      0.000        20.134    30.334
# WholeWeight    -1.6277      0.137    -11.864      0.000        -1.897    -1.359
# ==============================================================================
# Omnibus:                     1255.855   Durbin-Watson:                   1.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5973.157
# Skew:                           1.374   Prob(JB):                         0.00
# Kurtosis:                       8.176   Cond. No.                         93.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model_9 = smf.ols(formula = 'Rings ~ 0 + Length + Height + Diameter + VisceraWeight', data = df).fit().summary()
model_9
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rings   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.938
# Method:                 Least Squares   F-statistic:                 1.578e+04
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:18   Log-Likelihood:                -9914.2
# No. Observations:                4175   AIC:                         1.984e+04
# Df Residuals:                    4171   BIC:                         1.986e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Length           -3.8232      1.923     -1.989      0.047        -7.593    -0.054
# Height           23.1720      1.776     13.045      0.000        19.689    26.655
# Diameter         24.7846      2.550      9.718      0.000        19.785    29.785
# VisceraWeight    -8.0142      0.580    -13.809      0.000        -9.152    -6.876
# ==============================================================================
# Omnibus:                     1211.029   Durbin-Watson:                   1.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5806.431
# Skew:                           1.318   Prob(JB):                         0.00
# Kurtosis:                       8.141   Cond. No.                         57.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model_10 = smf.ols(formula = 'Rings ~ 0 + Length + Height * Diameter', data = df).fit().summary()
model_10
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rings   R-squared:                       0.939
# Model:                            OLS   Adj. R-squared:                  0.939
# Method:                 Least Squares   F-statistic:                 1.598e+04
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:18   Log-Likelihood:                -9889.5
# No. Observations:                4175   AIC:                         1.979e+04
# Df Residuals:                    4171   BIC:                         1.981e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Length            -12.4595      2.068     -6.024      0.000       -16.514    -8.405
# Height             44.4991      2.389     18.630      0.000        39.816    49.182
# Diameter           33.8274      2.706     12.501      0.000        28.522    39.133
# Height:Diameter   -58.8985      3.780    -15.581      0.000       -66.309   -51.488
# ==============================================================================
# Omnibus:                     1317.527   Durbin-Watson:                   1.037
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7175.482
# Skew:                           1.402   Prob(JB):                         0.00
# Kurtosis:                       8.778   Cond. No.                         79.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model_11 = smf.ols(formula = 'Rings ~ 0 + Length + Height + Diameter + ShellWeight', data = df).fit().summary()
model_11
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rings   R-squared:                       0.935
# Model:                            OLS   Adj. R-squared:                  0.935
# Method:                 Least Squares   F-statistic:                 1.505e+04
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:18   Log-Likelihood:                -10007.
# No. Observations:                4175   AIC:                         2.002e+04
# Df Residuals:                    4171   BIC:                         2.005e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Length          1.7160      2.014      0.852      0.394        -2.233     5.665
# Height         18.4710      1.837     10.053      0.000        14.869    22.073
# Diameter       15.1151      2.682      5.635      0.000         9.856    20.374
# ShellWeight     0.6359      0.495      1.284      0.199        -0.335     1.607
# ==============================================================================
# Omnibus:                     1023.644   Durbin-Watson:                   0.912
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3172.005
# Skew:                           1.246   Prob(JB):                         0.00
# Kurtosis:                       6.468   Cond. No.                         60.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model_12 = smf.ols(formula = 'Rings ~ 0 + Length * Height * Diameter * VisceraWeight', data = df).fit().summary()
model_12
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rings   R-squared:                       0.941
# Model:                            OLS   Adj. R-squared:                  0.940
# Method:                 Least Squares   F-statistic:                     4395.
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:19   Log-Likelihood:                -9823.5
# No. Observations:                4175   AIC:                         1.968e+04
# Df Residuals:                    4160   BIC:                         1.977e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------------------
# Length                                   0.8529     14.919      0.057      0.954       -28.397    30.103
# Height                                 -95.4002     20.988     -4.546      0.000      -136.547   -54.253
# Length:Height                          208.5296    130.697      1.596      0.111       -47.706   464.765
# Diameter                                58.1896     21.118      2.755      0.006        16.787    99.593
# Length:Diameter                       -108.2560     16.500     -6.561      0.000      -140.604   -75.908
# Height:Diameter                         49.8454    174.644      0.285      0.775      -292.549   392.240
# Length:Height:Diameter                 116.8123     80.214      1.456      0.145       -40.451   274.075
# VisceraWeight                          165.2174     49.420      3.343      0.001        68.328   262.107
# Length:VisceraWeight                  -214.8379    120.780     -1.779      0.075      -451.632    21.956
# Height:VisceraWeight                  -505.8795    351.315     -1.440      0.150     -1194.645   182.886
# Length:Height:VisceraWeight            324.5838    699.487      0.464      0.643     -1046.784  1695.952
# Diameter:VisceraWeight                -330.5683    163.263     -2.025      0.043      -650.652   -10.485
# Length:Diameter:VisceraWeight          538.1699    168.757      3.189      0.001       207.316   869.024
# Height:Diameter:VisceraWeight         1170.1720    899.946      1.300      0.194      -594.204  2934.548
# Length:Height:Diameter:VisceraWeight -1573.7635    936.488     -1.680      0.093     -3409.781   262.254
# ==============================================================================
# Omnibus:                     1286.607   Durbin-Watson:                   1.070
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4347.445
# Skew:                           1.541   Prob(JB):                         0.00
# Kurtosis:                       6.936   Cond. No.                     2.61e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.61e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model_13 = smf.ols(formula = 'Rings ~ 0 + Length * Height * Diameter * ShuckedWeight', data = df).fit().summary()
model_13
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rings   R-squared:                       0.946
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     4850.
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:19   Log-Likelihood:                -9629.7
# No. Observations:                4175   AIC:                         1.929e+04
# Df Residuals:                    4160   BIC:                         1.938e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------------------
# Length                                   5.7692     13.657      0.422      0.673       -21.006    32.544
# Height                                 -60.4042     19.826     -3.047      0.002       -99.273   -21.535
# Length:Height                          163.8959    113.738      1.441      0.150       -59.091   386.883
# Diameter                                30.3368     19.384      1.565      0.118        -7.667    68.340
# Length:Diameter                        -77.5371     13.797     -5.620      0.000      -104.587   -50.487
# Height:Diameter                        306.7889    153.616      1.997      0.046         5.619   607.959
# Length:Height:Diameter                -211.6101     70.863     -2.986      0.003      -350.539   -72.681
# ShuckedWeight                           33.1821     16.862      1.968      0.049         0.123    66.241
# Length:ShuckedWeight                    -7.6469     51.664     -0.148      0.882      -108.935    93.641
# Height:ShuckedWeight                  -688.8484    121.659     -5.662      0.000      -927.366  -450.331
# Length:Height:ShuckedWeight            623.5516    291.038      2.143      0.032        52.961  1194.142
# Diameter:ShuckedWeight                 -59.0440     68.967     -0.856      0.392      -194.257    76.169
# Length:Diameter:ShuckedWeight           57.6179     66.066      0.872      0.383       -71.908   187.144
# Height:Diameter:ShuckedWeight          892.9565    386.228      2.312      0.021       135.744  1650.169
# Length:Height:Diameter:ShuckedWeight  -960.2351    366.829     -2.618      0.009     -1679.416  -241.055
# ==============================================================================
# Omnibus:                     1221.053   Durbin-Watson:                   1.245
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3782.131
# Skew:                           1.494   Prob(JB):                         0.00
# Kurtosis:                       6.579   Cond. No.                     1.25e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.25e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model_14 = smf.ols(formula = 'Rings ~ 0 + Length * Height * Diameter * WholeWeight', data = df).fit().summary()
model_14
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rings   R-squared:                       0.941
# Model:                            OLS   Adj. R-squared:                  0.941
# Method:                 Least Squares   F-statistic:                     4434.
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:19   Log-Likelihood:                -9806.4
# No. Observations:                4175   AIC:                         1.964e+04
# Df Residuals:                    4160   BIC:                         1.974e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------------
# Length                                 4.1603     15.116      0.275      0.783       -25.476    33.796
# Height                               -72.6202     22.017     -3.298      0.001      -115.785   -29.455
# Length:Height                        148.9960    136.575      1.091      0.275      -118.764   416.756
# Diameter                              48.4463     21.581      2.245      0.025         6.136    90.756
# Length:Diameter                     -112.6591     18.207     -6.188      0.000      -148.355   -76.963
# Height:Diameter                      119.8578    185.925      0.645      0.519      -244.655   484.370
# Length:Height:Diameter                64.1965     94.264      0.681      0.496      -120.611   249.004
# WholeWeight                           34.0842     11.550      2.951      0.003        11.439    56.729
# Length:WholeWeight                   -23.9263     28.000     -0.855      0.393       -78.820    30.968
# Height:WholeWeight                  -157.8976     78.012     -2.024      0.043      -310.844    -4.952
# Length:Height:WholeWeight             55.8619    156.153      0.358      0.721      -250.281   362.004
# Diameter:WholeWeight                 -64.1424     37.046     -1.731      0.083      -136.772     8.487
# Length:Diameter:WholeWeight           78.9683     39.644      1.992      0.046         1.246   156.691
# Height:Diameter:WholeWeight          338.8938    195.943      1.730      0.084       -45.259   723.046
# Length:Height:Diameter:WholeWeight  -324.2672    210.715     -1.539      0.124      -737.381    88.846
# ==============================================================================
# Omnibus:                     1263.341   Durbin-Watson:                   1.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4089.212
# Skew:                           1.530   Prob(JB):                         0.00
# Kurtosis:                       6.761   Cond. No.                     1.10e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.1e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model_15 = smf.ols(formula = 'Rings ~ 0 + Length + Height + Diameter + ShellWeight + ShuckedWeight', data = df).fit().summary()
model_15
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rings   R-squared:                       0.952
# Model:                            OLS   Adj. R-squared:                  0.952
# Method:                 Least Squares   F-statistic:                 1.657e+04
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:19   Log-Likelihood:                -9376.6
# No. Observations:                4175   AIC:                         1.876e+04
# Df Residuals:                    4170   BIC:                         1.879e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Length            5.5428      1.735      3.194      0.001         2.141     8.945
# Height           14.5049      1.584      9.160      0.000        11.400    17.609
# Diameter         13.9169      2.307      6.032      0.000         9.394    18.440
# ShellWeight      17.1997      0.607     28.343      0.000        16.010    18.389
# ShuckedWeight   -13.4294      0.350    -38.331      0.000       -14.116   -12.743
# ==============================================================================
# Omnibus:                      926.227   Durbin-Watson:                   1.351
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2675.533
# Skew:                           1.152   Prob(JB):                         0.00
# Kurtosis:                       6.173   Cond. No.                         68.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model_16 = smf.ols(formula = 'Rings ~ 0 + VolumeLog + ShellWeight + ShuckedWeight', data = df).fit().summary()
model_16
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rings   R-squared:                       0.940
# Model:                            OLS   Adj. R-squared:                  0.940
# Method:                 Least Squares   F-statistic:                 2.186e+04
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:19   Log-Likelihood:                -9839.3
# No. Observations:                4175   AIC:                         1.968e+04
# Df Residuals:                    4172   BIC:                         1.970e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# VolumeLog        -1.2648      0.016    -80.175      0.000        -1.296    -1.234
# ShellWeight      32.3744      0.591     54.813      0.000        31.216    33.532
# ShuckedWeight    -6.9384      0.378    -18.353      0.000        -7.680    -6.197
# ==============================================================================
# Omnibus:                      553.796   Durbin-Watson:                   1.269
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1711.746
# Skew:                           0.687   Prob(JB):                         0.00
# Kurtosis:                       5.820   Cond. No.                         65.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model_17 = smf.ols(formula = 'Rings ~ 0 + VolumeLog + ShellWeight + ShuckedWeight', data = df).fit().summary()
model_17
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rings   R-squared:                       0.940
# Model:                            OLS   Adj. R-squared:                  0.940
# Method:                 Least Squares   F-statistic:                 2.186e+04
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:19   Log-Likelihood:                -9839.3
# No. Observations:                4175   AIC:                         1.968e+04
# Df Residuals:                    4172   BIC:                         1.970e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# VolumeLog        -1.2648      0.016    -80.175      0.000        -1.296    -1.234
# ShellWeight      32.3744      0.591     54.813      0.000        31.216    33.532
# ShuckedWeight    -6.9384      0.378    -18.353      0.000        -7.680    -6.197
# ==============================================================================
# Omnibus:                      553.796   Durbin-Watson:                   1.269
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1711.746
# Skew:                           0.687   Prob(JB):                         0.00
# Kurtosis:                       5.820   Cond. No.                         65.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model_18 = smf.ols(formula = 'Rings ~ 0 + VolumeLog * ShellWeight * ShuckedWeight', data = df).fit().summary()
model_18
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rings   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.954
# Method:                 Least Squares   F-statistic:                 1.249e+04
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:19   Log-Likelihood:                -9268.8
# No. Observations:                4175   AIC:                         1.855e+04
# Df Residuals:                    4168   BIC:                         1.860e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------------------------
# VolumeLog                              -0.5910      0.029    -20.678      0.000        -0.647    -0.535
# ShellWeight                           -12.7037      3.534     -3.595      0.000       -19.632    -5.775
# VolumeLog:ShellWeight                 -19.0191      1.170    -16.258      0.000       -21.312   -16.726
# ShuckedWeight                          17.5154      2.297      7.627      0.000        13.013    22.018
# VolumeLog:ShuckedWeight                 4.7424      0.747      6.350      0.000         3.278     6.207
# ShellWeight:ShuckedWeight              40.5031      4.514      8.972      0.000        31.653    49.353
# VolumeLog:ShellWeight:ShuckedWeight    27.1355      1.852     14.656      0.000        23.505    30.765
# ==============================================================================
# Omnibus:                      998.334   Durbin-Watson:                   1.390
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3245.473
# Skew:                           1.197   Prob(JB):                         0.00
# Kurtosis:                       6.595   Cond. No.                         577.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model_19 = smf.ols(formula = 'Rings ~ 0 + VolumeLog * WholeWeight', data = df).fit().summary()
model_19
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rings   R-squared:                       0.928
# Model:                            OLS   Adj. R-squared:                  0.928
# Method:                 Least Squares   F-statistic:                 1.802e+04
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:19   Log-Likelihood:                -10216.
# No. Observations:                4175   AIC:                         2.044e+04
# Df Residuals:                    4172   BIC:                         2.046e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------
# VolumeLog                -0.8637      0.027    -31.690      0.000        -0.917    -0.810
# WholeWeight              -3.7732      0.453     -8.335      0.000        -4.661    -2.886
# VolumeLog:WholeWeight    -3.7339      0.171    -21.865      0.000        -4.069    -3.399
# ==============================================================================
# Omnibus:                     1046.305   Durbin-Watson:                   0.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2836.751
# Skew:                           1.327   Prob(JB):                         0.00
# Kurtosis:                       6.044   Cond. No.                         51.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model_20 = smf.ols(formula = 'Rings ~ 0 + VolumeLog + ShellWeight * ShuckedWeight', data = df).fit().summary()
model_20
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Rings   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                 1.984e+04
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:19   Log-Likelihood:                -9462.4
# No. Observations:                4175   AIC:                         1.893e+04
# Df Residuals:                    4171   BIC:                         1.896e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------------
# VolumeLog                    -0.9225      0.019    -49.331      0.000        -0.959    -0.886
# ShellWeight                  39.2387      0.590     66.480      0.000        38.082    40.396
# ShuckedWeight                -0.0836      0.420     -0.199      0.842        -0.907     0.739
# ShellWeight:ShuckedWeight   -24.6564      0.858    -28.730      0.000       -26.339   -22.974
# ==============================================================================
# Omnibus:                      933.096   Durbin-Watson:                   1.315
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2660.988
# Skew:                           1.165   Prob(JB):                         0.00
# Kurtosis:                       6.141   Cond. No.                         96.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model_21 = smf.ols(formula = 'RingsLog ~ 0 + isAdult + VolumeLog * ShellWeight * ShuckedWeight', data = df).fit().summary()
model_21
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               RingsLog   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                 5.631e+04
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:19   Log-Likelihood:                 451.48
# No. Observations:                4175   AIC:                            -887.0
# Df Residuals:                    4167   BIC:                            -836.3
# Df Model:                           8
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------------------------
# isAdult                                 0.0778      0.009      8.609      0.000         0.060     0.095
# VolumeLog                              -0.2178      0.003    -78.134      0.000        -0.223    -0.212
# ShellWeight                            -3.6937      0.345    -10.714      0.000        -4.370    -3.018
# VolumeLog:ShellWeight                  -3.3197      0.115    -28.969      0.000        -3.544    -3.095
# ShuckedWeight                           2.9344      0.227     12.900      0.000         2.488     3.380
# VolumeLog:ShuckedWeight                 0.3271      0.073      4.452      0.000         0.183     0.471
# ShellWeight:ShuckedWeight              10.1238      0.442     22.888      0.000         9.257    10.991
# VolumeLog:ShellWeight:ShuckedWeight     6.1614      0.181     34.108      0.000         5.807     6.516
# ==============================================================================
# Omnibus:                      514.383   Durbin-Watson:                   1.425
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4764.257
# Skew:                          -0.225   Prob(JB):                         0.00
# Kurtosis:                       8.214   Cond. No.                         586.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model_22 = smf.ols(formula = 'RingsLog ~ 0 + isAdult + VolumeLog * ShellWeight * ShuckedWeight', data = df).fit().summary()
model_22
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               RingsLog   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                 5.631e+04
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:19   Log-Likelihood:                 451.48
# No. Observations:                4175   AIC:                            -887.0
# Df Residuals:                    4167   BIC:                            -836.3
# Df Model:                           8
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------------------------
# isAdult                                 0.0778      0.009      8.609      0.000         0.060     0.095
# VolumeLog                              -0.2178      0.003    -78.134      0.000        -0.223    -0.212
# ShellWeight                            -3.6937      0.345    -10.714      0.000        -4.370    -3.018
# VolumeLog:ShellWeight                  -3.3197      0.115    -28.969      0.000        -3.544    -3.095
# ShuckedWeight                           2.9344      0.227     12.900      0.000         2.488     3.380
# VolumeLog:ShuckedWeight                 0.3271      0.073      4.452      0.000         0.183     0.471
# ShellWeight:ShuckedWeight              10.1238      0.442     22.888      0.000         9.257    10.991
# VolumeLog:ShellWeight:ShuckedWeight     6.1614      0.181     34.108      0.000         5.807     6.516
# ==============================================================================
# Omnibus:                      514.383   Durbin-Watson:                   1.425
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4764.257
# Skew:                          -0.225   Prob(JB):                         0.00
# Kurtosis:                       8.214   Cond. No.                         586.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model_23 = smf.ols(formula = 'RingsLog ~ 0 + isAdult + VolumeLog + ShuckedWeightLog + ShellWeightLog', data = df).fit().summary()
model_23
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               RingsLog   R-squared:                       0.984
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                 6.453e+04
# Date:                Tue, 05 Jul 2016   Prob (F-statistic):               0.00
# Time:                        18:05:19   Log-Likelihood:                -698.87
# No. Observations:                4175   AIC:                             1406.
# Df Residuals:                    4171   BIC:                             1431.
# Df Model:                           4
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# isAdult              0.1929      0.011     17.278      0.000         0.171     0.215
# VolumeLog           -1.2494      0.009   -140.645      0.000        -1.267    -1.232
# ShuckedWeightLog     0.2139      0.017     12.947      0.000         0.182     0.246
# ShellWeightLog       1.2908      0.023     55.998      0.000         1.246     1.336
# ==============================================================================
# Omnibus:                      685.243   Durbin-Watson:                   1.491
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10130.075
# Skew:                          -0.300   Prob(JB):                         0.00
# Kurtosis:                      10.607   Cond. No.                         27.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model_23 = smf.ols(formula = 'RingsLog ~ 0 + isAdult + VolumeLog + ShuckedWeightLog + ShellWeightLog', data = df).fit()
model_23.resid.plot(kind = 'hist', bins = 250, figsize = (8, 8))

plt.show()

# %% [markdown]
# ### q-q plot (e.g., residuals) against a normal distribution

# %%
figure, ax = plt.subplots(figsize = (8, 8))
figure = sm.qqplot(model_23.resid, line = 's', ax = ax)

plt.show()

# %% [markdown]
# ## Found Model, Train Data

# %%
# Train sample
train_df = df.sample(frac = .6, random_state = 1)
test_df = df.drop(train_df.index)

# %%
#train_X = train_df[ ['VolumeLog', 'ShellWeight', 'ShuckedWeight'] ]
# do a qqplot
#train_X = train_df[ ['isAdult', 'VolumeLog', 'ShellWeight', 'ShuckedWeight'] ]
train_X = train_df[['isAdult', 'VolumeLog', 'ShellWeightLog', 'ShuckedWeightLog']]
#train_X = train_df[['isAdult', 'VolumeLog', 'ShellShuckedWeight']]
train_y = train_df['RingsLog']
# stepwise regression goes thru a dataset and chooses a var and gives you an eventual set of columns

# %%
model = linear_model.LinearRegression()
# If we want to force the intercept to 0:
#model = linear_model.LinearRegression(fit_intercept = False)

# Fit the training
model.fit(train_X, train_y)
# This is a diff kind of cross validation with a bigger training set
print model.score(train_X, train_y)
# Cross validation divides the training df into training and validation
print cross_validation.cross_val_score(model, train_X, train_y, cv = 10)
print cross_validation.cross_val_score(model, train_X, train_y, cv = 10).mean()
# Out:
# 0.634235249031
# [ 0.58352755  0.64978985  0.62041289  0.64366072  0.57440948  0.65080792
#   0.59351608  0.68077869  0.62550571  0.66215764]
# 0.6284566527

# %%
# These are the y-values for the actual regression line
model.predict(train_X)

# %% [markdown]
# ## Test on Data

# %%
test_X = test_df[['isAdult', 'VolumeLog', 'ShellWeightLog', 'ShuckedWeightLog']]
test_y = test_df['RingsLog']

# %%
model = linear_model.LinearRegression()
# If we want to force the intercept to 0:
#model = linear_model.LinearRegression(fit_intercept = False)

# Fit the training
model.fit(test_X, test_y)
# This is a diff kind of cross validation with a bigger training set
print model.score(test_X, test_y)
# Cross validation divides the training df into training and validation
print cross_validation.cross_val_score(model, test_X, test_y, cv = 10)
print cross_validation.cross_val_score(model, test_X, test_y, cv = 10).mean()

# %%
model.predict(test_X)

# %%
normal_array = np.random.normal(10, 1, size = 100)

figure, ax = plt.subplots(figsize = (8, 8))
figure = sm.qqplot(normal_array, line = 's', ax = ax)
plt.show()
